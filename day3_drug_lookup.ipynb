# %%
# My first Python code - Day 1
name = "Nazeer Basha"
print("Hello, my nahe is", name)

# Simple Math
X = 10
Y = 5
print("Sum :", X + Y)
print("multiply :", X * Y)

# AL list of Pharma terms

pharma_terms = ["Clinical trial", "API", "SOP", "Adverse event","pharmacovigilance"]

print("\nPharma terms I Will Work With :")
for term in pharma_terms :
  print("-", term)
# Out:
# Hello, my nahe is Nazeer Basha
# Sum : 15
# multiply : 50
#
# Pharma terms I Will Work With :
# - Clinical trial
# - API
# - SOP
# - Adverse event
# - pharmacovigilance

# %% [markdown]
# # String text value in Python

# %%
# String text value in Python

drug_name = "Paracetamol"
drug_use  = "pain relief and fever reduction"

sentence_1 = drug_name +" is used for "+ drug_use
print (sentence_1)

sentence_2 = (f"{drug_name} is used for {drug_use}")
print (sentence_2)
# Out:
# Paracetamol is used for pain relief and fever reduction
# Paracetamol is used for pain relief and fever reduction

# %%
# A function is a reusable block of code
# def means "define a new function"

def describe_drug(name, use):
  sentence = f"{name} is used for {use}"
  print (sentence)

# Now CALL the function with different drugs

describe_drug("Metformin", "managing type 2 diabetes")
describe_drug("Atorvastatin", "lowering cholesterol")
describe_drug("Paracetamol", "pain relief and fever reduction")
# Out:
# Metformin is used for managing type 2 diabetes
# Atorvastatin is used for lowering cholesterol
# Paracetamol is used for pain relief and fever reduction

# %%
# Pharma Drug Glossary — Day 2 Project

def describe_drug(name, category, use):
  print(f"\nDrug : {name}")
  print(f"category : {category}")
  print(f"use : {use}")
  print("_" * 35)

# Call the function for 5 drugs

describe_drug("Paracetamol", "Analgesic", "Pain relief and fever reduction")
describe_drug("Metformin", "Antidiabetic", "Managing type 2 diabetes")
describe_drug("Atorvastatin", "Statin", "Lowering cholesterol levels")
describe_drug("Amoxicillin", "Antibiotic", "Treating bacterial infections")
describe_drug("Omeprazole", "PPI", "Reducing stomach acid")
# Out:
# Drug : Paracetamol
# category : Analgesic
# use : Pain relief and fever reduction
# ___________________________________
#
# Drug : Metformin
# category : Antidiabetic
# use : Managing type 2 diabetes
# ___________________________________
#
# Drug : Atorvastatin
# category : Statin
# use : Lowering cholesterol levels
# ___________________________________
#
# Drug : Amoxicillin
# category : Antibiotic
# use : Treating bacterial infections
# ___________________________________
#
# Drug : Omeprazole
# category : PPI
# use : Reducing stomach acid
# ___________________________________

# %%
# Pharma Drug Glossary — Day 2 Project

def describe_drug(name, category, use):
  print(f"\nDrug : {name}")
  print(f"category : {category}")
  print(f"use : {use}")
  print("_" * 35)

# Call the function for 5 drugs

# Pharma Drug Glossary — Day 2 Project

def describe_drug(name, category, use):
  print(f"\nDrug : {name}")
  print(f"category : {category}")
  print(f"use : {use}")
  print("_" * 35)

# Call the function for 5 drugs

describe_drug("Paracetamol")
describe_drug("Metformin")
describe_drug("Atorvastatin")
describe_drug("Amoxicillin")
describe_drug("Omeprazole")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10739/3683068567.py in <cell line: 0>()
#      19 # Call the function for 5 drugs
#      20
# ---> 21 describe_drug("Paracetamol")
#      22 describe_drug("Metformin")
#      23 describe_drug("Atorvastatin")
#
# TypeError: describe_drug() missing 2 required positional arguments: 'category' and 'use'

# %% [markdown]
# A dictionary — key: value pairs

# %%
# A dictionary — key: value pairs
drug = {
    "name" : "Metformin",
    "category" : "Antidiabetic",
    "use" : "Managing type 2 diabetes",
    "side_effects" : "Nausea, stomach upset"
}

# Access a value using its key
print (drug["name"])
print (drug["category"])
print (drug["use"])
print (drug["side_effects"])
# Out:
# Metformin
# Antidiabetic
# Managing type 2 diabetes
# Nausea, stomach upset

# %%
# Dictionary of dictionaries — like a mini database

pharma_db = {
    "Metformin" : {
        "category": "Antidiabetic",
        "use": "Managing type 2 diabetes",
        "side_effects": "Nausea, stomach upset"
    },

    "Amoxicillin" : {
        "category" : "Antibiotic",
        "use" : "Treating bacterial infections",
        "side_effects" : "Rash, diarrhea"
    },

    "Omeprazole" : {
        "category" : "PPI",
        "use" : "Reducing stomach acid",
        "side_effects" : "Headache, nausea"
    }
}

print (pharma_db["Metformin"])
print (pharma_db["Amoxicillin"]["use"])
# Out:
# {'category': 'Antidiabetic', 'use': 'Managing type 2 diabetes', 'side_effects': 'Nausea, stomach upset'}
# Treating bacterial infections

# %%
# Drug Lookup Tool — Day 3 Project

pharma_db = {
    "Metformin": {
        "category": "Antidiabetic",
        "use": "Managing type 2 diabetes",
        "side_effects": "Nausea, stomach upset"
    },
    "Amoxicillin": {
        "category": "Antibiotic",
        "use": "Treating bacterial infections",
        "side_effects": "Rash, diarrhea"
    },
    "Omeprazole": {
        "category": "PPI",
        "use": "Reducing stomach acid",
        "side_effects": "Headache, nausea"
    },
    "Paracetamol": {
        "category": "Analgesic",
        "use": "Pain relief and fever reduction",
        "side_effects": "Rare at normal doses"
    },
    "Atorvastatin": {
        "category": "Statin",
        "use": "Lowering cholesterol levels",
        "side_effects": "Muscle pain, liver issues"
    }
}

def lookup_drug(drug_name) :
  if drug_name in pharma_db :
    drug = pharma_db[drug_name]
    print(f"\ndrug : {drug_name}")
    print(f"category : {drug['category']}")
    print(f"use : {drug['use']}")
    print(f"side_effects : {drug['side_effects']}")
    print("_" * 40)
  else:
    print(f"\n '{drug_name}' not found in database.")

 # Test the lookup

lookup_drug("Metformin")
lookup_drug("Paracetamol")
lookup_drug("Ibuprofen")
# Out:
# drug : Metformin
# category : Antidiabetic
# use : Managing type 2 diabetes
# side_effects : Nausea, stomach upset
# ________________________________________
#
# drug : Paracetamol
# category : Analgesic
# use : Pain relief and fever reduction
# side_effects : Rare at normal doses
# ________________________________________
#
#  'Ibuprofen' not found in database.
